# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("statistics.csv")
df
# Out:
#        ID                                               name      RMSE  \
# 0   xvxzd  Full quantum chemical calculation of free ener...  0.680076
# 1   gyuhx                                              S+pKa  0.731995
# 2   xmyhm                                    ACD/pKa Classic  0.786546
# 3   nb017                                               MoKa  0.942726
# 4   nb007                                          Epik Scan  0.945751
# 5   yqkga            ReSCoSS conformations // COSMOtherm pKa  1.010238
# 6   nb010                                   Epik Microscopic  1.028061
# 7   8xt50  ReSCoSS conformations // DSD-BLYP-D3 reranking...  1.071430
# 8   nb013                                             Jaguar  1.103116
# 9   nb015  Chemicalize v18.23 (ChemAxon MarvinSketch v18.23)  1.272256
# 10  p0jba  macroscopic pKa prediction from microscopic pK...  1.314747
# 11  37xm8                                      ACD/pKa GALAS  1.413110
# ...

# %%
median_rmse = np.median(df["RMSE"])
median_rmse
# Out:
# 1.8057173000139368
